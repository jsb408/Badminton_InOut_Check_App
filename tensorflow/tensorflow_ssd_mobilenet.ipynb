# %% [markdown]
# <a href="https://colab.research.google.com/github/UJHa/Badminton_InOut_Check_App/blob/master/tensorflow_ssd_mobilenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [RUN : 1]
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# [RUN : 2]
cd drive/My Drive/badminton
# Out:
# /content/drive/My Drive/badminton

# %%
## Create directory to store your model data
## Create directory to store your pre trained models and their related config files
# !mkdir data
# !mkdir models

# %%
## Clone tensorflow model scripts
# !git clone https://github.com/tensorflow/models tf-models

# %%
## To install COCO API
## [[[  in lastly, used coco_clone from github   ]]]

# !cd tf-models
# !git clone https://github.com/cocodataset/cocoapi.git
# !cd cocoapi/PythonAPI
# !make

# %%
# Copy compiled modules
# cp -r pycocotools $PROJECT_DIR/tf-models/research/

# %%
# Copy compiled modules
# cp -r pycocotools ../../research/

# %%
## Install Protobuf (find release for your system - https://github.com/protocolbuffers/protobuf/releases)
# !curl -L https://github.com/protocolbuffers/protobuf/releases/download/v3.9.2/protoc-3.9.2-osx-x86_64.zip -o protobuf.zip 
# !unzip ./protobuf.zip
# !rm ./protobuf.zip
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# [RUN : 3]
cd tf-models/research
# Out:
# /content/drive/My Drive/badminton/tf-models/research

# %%
# [RUN : 4]
## Import models for object_detection
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# [RUN : 5]
## Add Tensorflow Libraries to PYTHONPATH
% set_env PYTHONPATH=/content/drive/My Drive/badminton/tf-models/research:/content/drive/My Drive/badminton/tf-models/research/slim
# Out:
# env: PYTHONPATH=/content/drive/My Drive/badminton/tf-models/research:/content/drive/My Drive/badminton/tf-models/research/slim

# %%
# [RUN : 5-1]
## Test the installation
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# ...

# %%
## images, test/train.record, labelmap.pbtxt in data folder
## Now, we have all the required files ready in data folder.

# %%
## Download pre-trained model ==> in models folder.
# !curl -L http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz -o ssd_mobilenet_v2_quantized.tar.gz
# !tar -xvf ssd_mobilenet_v2_quantized.tar.gz
# !rm ssd_mobilenet_v2_quantized.tar.gz

# %%
### file information ###
## model.ckpt — checkpoints of your model (pre-trained model / partially-trained model) with estimators for further training.
## pipeline.config — configs of the model, training data, evaluation data and etc.

# %%
## Update model pipeline configurations

# %%
# [RUN : 6]
# Learning...
# if ckpt-0: 37:36[click to run] ~ 39:35[activate first step] => about 2 min to start learning (19.12.14)

# !python object_detection/model_main.py \
    --pipeline_config_path=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/pipeline.config \
    --model_dir=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03 \
    --num_train_steps=5000 \
    --sample_1_of_n_eval_examples=1 \
    --alsologtostderr
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From object_detection/model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
## helped metrics per category successfully on github
## cocoapi_clone from some user for us
# !git clone https://github.com/philippschw/cocoapi

# %%
### tflite converting

# %%
# [RUN : 7]
### export_tflite_ssd_graph.py 실행
### tflite로 변환하기 전, optimizing 해주는 작업

#export PROJECT_DIR=<YOUR PROJECT DIRECTORY>
#export MODEL_DIR=$PROJECT_DIR/models/<YOUR SSD MODEL>

#export TF_API_DIR=$PROJECT_DIR/tf-models/research
#export MODEL_CONFIG=$MODEL_DIR/pipeline.config
#export CHECKPOINT_PATH=$MODEL_DIR/model.ckpt-<CHECKPOINT NUMBER>  --> input latest number
#export OUTPUT_DIR=$MODEL_DIR/tmp/tflite 

# model_dir=ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03
# ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.pipeline.config
# !python object_detection/export_tflite_ssd_graph.py \
--pipeline_config_path=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/pipeline.config \
--trained_checkpoint_prefix=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/model.ckpt-5000 \
--output_directory=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/tmp/tflite \
--add_postprocessing_op=true
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/badminton/tf-models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From object_detection/export_tflite_ssd_graph.py:143: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
#@title 기본 제목 텍스트
## This will give us two files (tflite_graph.pb&tflite_graph.pbtxt ) 
## in the specified output directory (/tmp/tflite).

# %%
# [RUN : 8 - END]
## bazel 명령어의 workspace의 parent-directory에 공백이 포함되어있으면 실행되지 않음.
## models 파일을 content에 복사하여 작업 진행.
## 그래도 오류 발생하여 bazel을 빼고 바로 toco로 실행 => 성공

# !toco --output_file=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/tmp/tflite/detect-5000.tflite \
--graph_def_file=/content/drive/My\ Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/tmp/tflite/tflite_graph.pb \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=QUANTIZED_UINT8 \
--mean_values=128 \
--std_dev_values=128 \
--change_concat_input_ranges=false \
--allow_custom_ops
# Out:
# 2019-12-14 00:56:09.028377: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-12-14 00:56:09.041840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-12-14 00:56:09.042492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-12-14 00:56:09.042751: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-12-14 00:56:09.044142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# ...

# %%
### confirm to tensorboard

! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip ngrok-stable-linux-amd64.zip
# Out:
# --2019-12-14 08:01:37--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.82.169.244, 34.237.57.234, 54.161.51.119, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.82.169.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.3’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  16.7MB/s    in 0.8s
#
# 2019-12-14 08:01:38 (16.7 MB/s) - ‘ngrok-stable-linux-amd64.zip.3’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok

# %%
LOG_DIR = '/content/drive/My Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')

! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://2f96d7ee.ngrok.io

# %%
# Out:
# http://e49e5f2c.ngrok.io

# %%
LOG_DIR = '/content/drive/My Drive/badminton/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 7000 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 7000 &')

# %%
#@title additional codes [don't need] { form-width: "90%", display-mode: "form" }

# %%
## install bazel
BAZEL_VERSION = '0.20.0'
# !wget https://github.com/bazelbuild/bazel/releases/download/{BAZEL_VERSION}/bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !chmod +x bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh
# !./bazel-{BAZEL_VERSION}-installer-linux-x86_64.sh

# %%
cd tensorflow

# %%
# !bazel run -c opt tensorflow/lite/toco:toco -- \
--input_file=/content/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/tmp/tflite/tflite_graph.pb \
--output_file=/content/models/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/tmp/tflite/detect.tflite \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=QUANTIZED_UINT8 \
--mean_values=128 \
--std_values=128 \
--change_concat_input_ranges=false \
--allow_custom_ops

# %%
# Out:
# /bin/bash: rails: command not found
